# %%
import pandas as pd
import numpy as np
import pickle
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accuracy_score

# %%
pd.set_option('display.max_columns', None)

# %%
data=pd.read_csv("gender.csv")
data.head()
# Out:
#    age  height_cm  weight_kg   bmi  shoulder_width_cm  waist_circumference_cm  \
# 0   24      172.6       82.5  27.7               46.4                   100.9
# 1   26      163.1       65.8  24.7               36.5                    70.2
# 2   25      181.7      109.3  33.1               45.8                   103.1
# 3   68      172.3       77.4  26.1               48.3                    97.6
# 4   63      178.4       81.9  25.7               46.1                   108.8
#
#    hip_circumference_cm  waist_hip_ratio  chest_circumference_cm  \
# 0                  89.5            1.128                   101.0
# 1                 101.6            0.691                    94.3
# 2                  97.8            1.055                   102.7
# 3                  92.5            1.055                   111.4
# 4                  91.9            1.184                    95.5
#
#    hand_length_cm  foot_length_cm  neck_circumference_cm  \
# ...

# %%
data.shape
# Out:
# (200, 23)

# %%
x=data.iloc[:,0:22].values
x
# Out:
# array([[24, 172.6, 82.5, ..., 1.244, 'male', 'young'],
#        [26, 163.1, 65.8, ..., 1.308, 'female', 'young'],
#        [25, 181.7, 109.3, ..., 1.291, 'male', 'young'],
#        ...,
#        [28, 169.1, 78.3, ..., 1.178, 'male', 'young'],
#        [29, 171.8, 56.4, ..., 1.223, 'female', 'young'],
#        [84, 162.1, 88.5, ..., 1.17, 'male', 'old']],
#       shape=(200, 22), dtype=object)

# %%
y=data.iloc[:,-1].values
y
# Out:
# array(['young_male', 'young_female', 'young_male', 'old_male', 'old_male',
#        'young_female', 'young_male', 'young_male', 'old_male', 'old_male',
#        'young_female', 'old_female', 'young_female', 'old_male',
#        'adult_female', 'young_female', 'adult_male', 'young_male',
#        'young_female', 'adult_female', 'young_female', 'old_female',
#        'adult_male', 'old_male', 'old_female', 'old_female', 'old_male',
#        'young_male', 'adult_male', 'young_male', 'adult_male',
#        'adult_female', 'young_female', 'adult_female', 'old_male',
#        'old_female', 'old_male', 'old_male', 'young_male', 'adult_female',
#        'old_female', 'old_male', 'young_female', 'young_male',
#        'adult_female', 'young_female', 'old_male', 'young_female',
#        'adult_female', 'young_female', 'young_female', 'old_male',
#        'old_female', 'old_female', 'adult_female', 'young_male',
#        'young_female', 'young_male', 'old_male', 'old_male', 'old_female',
# ...

# %%
# Create a dataframe from x to use get_dummies
x_df = pd.DataFrame(x)

# Apply get_dummies to encode categorical columns (20 and 21)
x_df = pd.get_dummies(x_df, columns=[20, 21], drop_first=True)

# Convert back to numpy array
x = x_df.values

# %%
x
# Out:
# array([[24, 172.6, 82.5, ..., True, False, True],
#        [26, 163.1, 65.8, ..., False, False, True],
#        [25, 181.7, 109.3, ..., True, False, True],
#        ...,
#        [28, 169.1, 78.3, ..., True, False, True],
#        [29, 171.8, 56.4, ..., False, False, True],
#        [84, 162.1, 88.5, ..., True, True, False]],
#       shape=(200, 23), dtype=object)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
p=knn.score(x_train,y_train)
p
# Out:
# 0.9125

# %%
# Original input row (22 values including 2 categorical)
input_data = [24, 172.6, 82.5, 27.7, 46.4, 100.9, 89.5, 1.128, 101.0, 16.0, 25.0,
                          39.2, 15.6, 121.6, 77.0, 40.7, 67.0, 115.0, 11.2, 1.244, "male", "young"]

input_df = pd.DataFrame([input_data], columns=list(range(22)))

# define categorical columns before using them
columns_to_encode = [20, 21]

# apply one-hot encoding (do this once)
input_df = pd.get_dummies(input_df, columns=columns_to_encode, drop_first=True)

# align to training features
training_features = list(x_df.columns)
input_df = input_df.reindex(columns=training_features, fill_value=0)
input_df = input_df.astype(float)

input_array = input_df.values
prediction = knn.predict(input_array)
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       2 input_data = [24, 172.6, 82.5, 27.7, 46.4, 100.9, 89.5, 1.128, 101.0, 16.0, 25.0,
#       3                           39.2, 15.6, 121.6, 77.0, 40.7, 67.0, 115.0, 11.2, 1.244, "male", "young"]
#       5 input_df = pd.DataFrame([input_data], columns=list(range(22)))
# ----> 6 input_df = pd.get_dummies(input_df, columns=columns_to_encode, drop_first=True)
#       8 training_features = list(x_df.columns)
#       9 columns_to_encode = [20, 21]
#
# NameError: name 'columns_to_encode' is not defined

# %%
with open('knn_model_pickle.pkl', 'wb') as f:
    pickle.dump(knn, f)
with open('preprocessor_pickle.pkl', 'wb') as f:
    pickle.dump(preprocessor, f)

print("✅ Models saved successfully!")
print(f"knn_model.pkl - {knn.__class__.__name__}")
print(f"preprocessor.pkl - {preprocessor.__class__.__name__}")

# Step 9: Test the saved model
print("\nTesting saved model...")
test_sample = X.iloc[[0]]  # Take first row as test
sample_processed = preprocessor.transform(test_sample)
prediction = knn.predict(sample_processed)
print(f"Sample prediction: {prediction[0]}")
